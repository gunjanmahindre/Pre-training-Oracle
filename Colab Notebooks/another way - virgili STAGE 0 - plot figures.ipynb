# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  
import math
import seaborn as sns
import pandas as pa

# %% [markdown]
# ## Mean error

# %%
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 0/"
m1 = np.loadtxt(path + '1_5_10/mean_error.txt')
m1
# Out:
# array([25.57577153, 25.68069307, 27.42663657, 27.31356694, 31.79347826,
#        25.        , 29.41176471, 35.71428571])

# %% [markdown]
# For sensitivity error plot

# %%
#  percentage sampled
# p = [40, 20, 10, 1, 0.5, 0.1, 0.0001]
p = [80, 60, 40, 20, 10, 1, 0.5, 0.1]

# load from a file: MEAN ERROR

# path =  "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 0/"
path =  "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/10s/"

# m1 = np.loadtxt(path + '8_10_12/mean_error.txt')[1:]

m1 = np.loadtxt(path + '1_5_10/mean_error.txt')
m2 = np.loadtxt(path + '10_15_20/mean_error.txt')
m3 = np.loadtxt(path + '20_25_30/mean_error.txt')
m4 = np.loadtxt(path + '30_35_40/mean_error.txt')
m5 = np.loadtxt(path + '40_45_50/mean_error.txt')
m6 = np.loadtxt(path + '50_55_60/mean_error.txt')
m7 = np.loadtxt(path + '60_65_70/mean_error.txt')
m8 = np.loadtxt(path + '70_75_80/mean_error.txt')
m9 = np.loadtxt(path + '80_85_90/mean_error.txt')
m10 = np.loadtxt(path + '90_95_100/mean_error.txt')

# %%
np.mean(m1), np.mean(m2), np.mean(m3), np.mean(m4),np.mean(m5), np.mean(m6)
# Out:
# (16.771754324558557,
#  18.311261300643146,
#  20.341622035093465,
#  24.089519455424465,
#  26.311994659529425,
#  26.93041113580899)

# %%
m = np.column_stack((m1, m2, m3, m4, m5, m6, m7, m8, m9, m10))
m
# Out:
# array([[15.8322699 , 16.30420388, 15.38131837, 16.00361033, 16.71490492,
#         16.60724914, 16.7006274 , 16.33700693, 16.37448825, 16.34460008],
#        [16.0057081 , 17.23812689, 15.94525028, 16.63558634, 17.3083284 ,
#         17.71207418, 17.72226039, 17.14054063, 17.29235429, 17.19780988],
#        [16.56174968, 16.80723946, 16.66839687, 17.71263727, 18.23516643,
#         18.95023516, 18.49318696, 19.07139334, 18.35355721, 18.76726801],
#        [17.10921535, 17.93362788, 18.71991167, 20.57230785, 22.12002605,
#         24.359962  , 22.33903399, 22.42359707, 22.18674808, 21.89978861],
#        [18.34786102, 21.18552373, 23.48075858, 26.1935763 , 29.77329374,
#         29.57297173, 28.99922219, 28.46275307, 28.48533695, 28.60119935],
#        [18.11641454, 21.43569076, 27.07722806, 34.65960863, 37.95535676,
#         38.24761157, 38.04225474, 37.28136472, 36.67790165, 36.62275037],
#        [17.32371382, 19.94442997, 23.69241427, 31.96546123, 34.94632964,
# ...

# %%
m[0]
# Out:
# array([15.8322699 , 16.30420388, 15.38131837, 16.00361033, 16.71490492,
#        16.60724914, 16.7006274 , 16.33700693, 16.37448825, 16.34460008])

# %%
m.shape
# Out:
# (8, 10)

# %%
# load from a file: std dev for mean error

path =  "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/stage 0/"
# path =  "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 0/"


# s1 = np.loadtxt(path + '8_10_12/mean_std.txt')[1:]
                
# s1 = np.loadtxt(path + '1_5_10/mean_std.txt')
# s2 = np.loadtxt(path + '10_15_20/mean_std.txt')
# s3 = np.loadtxt(path + '20_25_30/mean_std.txt')
# s4 = np.loadtxt(path + '30_35_40/mean_std.txt')
# s5 = np.loadtxt(path + '40_45_50/mean_std.txt')
# s6 = np.loadtxt(path + '50_55_60/mean_std.txt')
# s7 = np.loadtxt(path + '60_65_70/mean_std.txt')
# s8 = np.loadtxt(path + '70_75_80/mean_std.txt')
# s9 = np.loadtxt(path + '80_85_90/mean_std.txt')
# s10 = np.loadtxt(path + '90_95_100/mean_std.txt')

s1 = np.loadtxt(path + '1_5_10/mean_STD.txt')
s2 = np.loadtxt(path + '10_15_20/mean_STD.txt')
s3 = np.loadtxt(path + '20_25_30/mean_STD.txt')
s4 = np.loadtxt(path + '30_35_40/mean_STD.txt')
s5 = np.loadtxt(path + '40_45_50/mean_STD.txt')
s6 = np.loadtxt(path + '50_55_60/mean_STD.txt')
s7 = np.loadtxt(path + '60_65_70/mean_STD.txt')
s8 = np.loadtxt(path + '70_75_80/mean_STD.txt')
s9 = np.loadtxt(path + '80_85_90/mean_STD.txt')
s10 = np.loadtxt(path + '90_95_100/mean_STD.txt')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
len(m5)
# Out:
# 9

# %%
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/training variation - test performance/8_10_12/"


#  percentage sampled
# p = [60, 20, 0.1]
# deletion % = 20, 40, 60, 80, 90, 99, 99,5, 99.9
# p = [80, 60, 40, 20, 10, 1, 0.5, 0.1]
p = [1,10,20,30,40,50,60,70,80,90]

# m1 = np.loadtxt(path + 'mean_error.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')


# # # # # window: [8,10,12] test on 11
# ax = plt.plot(p, m1,color='lightcoral', linewidth=10, linestyle='--', markersize = 30,marker = "D", markeredgecolor='black',label = "[8,10,12] tested on 11")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "lightcoral")


# window: [1,2,3]
ax = plt.plot(p, m[0],color='lightcoral', linewidth=10, linestyle='--', markersize = 30,marker = "D", markeredgecolor='black',label = "80%")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "lightcoral")

# window: [3,4,5]
ax = plt.plot(p, m[1],color='orange', linewidth=10, linestyle='--', markersize = 30,marker = "1", markeredgecolor='black',label = "60%")
# plt.fill_between(p, m2-s2,m2+s2,alpha=.4, facecolor = "orange")

# window: [5,6,7]
ax = plt.plot(p, m[2],color='brown', linewidth=10, linestyle='--', markersize = 30,marker = "2", markeredgecolor='black',label = "40%")
# plt.fill_between(p, m3-s3,m3+s3,alpha=.4, facecolor = "brown")

# window: [7,8,9]
ax = plt.plot(p, m[3],color='blue', linewidth=10, linestyle='--', markersize = 30,marker = "3", markeredgecolor='black',label = "20%")
# plt.fill_between(p, m4-s4,m4+s4,alpha=.4, facecolor = "blue")

# window: [9,10,11]
ax = plt.plot(p, m[4],color='black', linewidth=10, linestyle='--', markersize = 30,marker = "4", markeredgecolor='black',label = "10%")
# plt.fill_between(p, m5-s5,m5+s5,alpha=.4, facecolor = "black")

# window: [11,12,13]
ax = plt.plot(p, m[5],color='yellow', linewidth=10, linestyle='--', markersize = 30,marker = "s", markeredgecolor='black',label = "1%")
# plt.fill_between(p, m6-s6,m6+s6,alpha=.4, facecolor = "yellow")

# window: [13,14,15]
ax = plt.plot(p, m[6],color='red', linewidth=10, linestyle='--', markersize = 30,marker = "*", markeredgecolor='black',label = "0.5%")
# plt.fill_between(p, m7-s7,m7+s7,alpha=.4, facecolor = "red")

# window: [1,2,3]
ax = plt.plot(p, m[7],color='darkviolet', linewidth=10, linestyle='--', markersize = 30,marker = "3", markeredgecolor='black',label = "0.1%")
# plt.fill_between(p, m8-s8,m8+s8,alpha=.4, facecolor = "darkviolet")

# # window: [3,4,5]
# ax = plt.plot(p, m9,color='gray', linewidth=10, linestyle='--', markersize = 30,marker = "4", markeredgecolor='black',label = "[80,85,90]")
# # plt.fill_between(p, m9-s9,m9+s9,alpha=.4, facecolor = "gray")

# # window: [5,6,7]
# ax = plt.plot(p, m10,color='teal', linewidth=10, linestyle='--', markersize = 30,marker = "s", markeredgecolor='black',label = "[90,95,100]")
# # plt.fill_between(p, m10-s10,m10+s10,alpha=.4, facecolor = "teal")



plt.legend()
# plt.xscale('log')
# plt.title('Train Bombing network - STAGE 0', fontsize = 60)
plt.title('Virgili Emails network - STAGE 0', fontsize = 60)
# plt.title('Facebook network - STAGE 0', fontsize = 60)
plt.xlabel('Parameter window', fontsize = 60)
plt.ylabel('Mean Error', fontsize = 60)
plt.rcParams['figure.figsize'] = [25, 18]
plt.xticks([1, 10, 20, 30, 40, 50, 60, 70, 80, 90], ['[1,5,10]', '[10,15,20]', '[20,25,30]', '[30,35,40]', '[40,45,50]', '[50,55,60]', '[60,65,70]', '[70,75,80]', '[80,85,90]', '[90,95,100]'])
plt.tick_params(axis='x', rotation=70)

# We change the fontsize of minor ticks label 
plt.tick_params(axis='both', which='major', labelsize=40)
plt.tick_params(axis='both', which='minor', labelsize=40)
plt.rc('legend',fontsize=40)

# fname = 'virgili_results_window_comparisons.png'
# # # plt.savefig(fname, dpi=1000)
# path = 'C:/Users/gunjan/Google Drive/PhD work/Projects/HA Journal version/results/training variations/'
# plt.savefig(path + fname)

plt.show()

# %%
#  percentage sampled
# p = [40, 20, 10, 1, 0.5, 0.1, 0.0001]
p = [80, 60, 40, 20, 10, 1, 0.5, 0.1, 0.0001]

path =  "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/10s/"
# path =  "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/stage 0/"
# path =  "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 0/"

# m1 = np.loadtxt(path + '8_10_12/mean_error.txt')[1:]

m1 = np.loadtxt(path + '1_5_10/abs_error.txt')
m2 = np.loadtxt(path + '10_15_20/abs_error.txt')
m3 = np.loadtxt(path + '20_25_30/abs_error.txt')
m4 = np.loadtxt(path + '30_35_40/abs_error.txt')
m5 = np.loadtxt(path + '40_45_50/abs_error.txt')
m6 = np.loadtxt(path + '50_55_60/abs_error.txt')
m7 = np.loadtxt(path + '60_65_70/abs_error.txt')
m8 = np.loadtxt(path + '70_75_80/abs_error.txt')
m9 = np.loadtxt(path + '80_85_90/abs_error.txt')
m10 = np.loadtxt(path + '90_95_100/abs_error.txt')

# %%
# load from a file:

# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili/round 2 all percentages - for observed entries/"
path =  "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 0/"

# s1 = np.loadtxt(path + '8_10_12/abs_std.txt')[1:]


# path = "C:/Users/gunjan/Google Drive/PhD work/Projects/parameter estimation/virgili/"

s1 = np.loadtxt(path + '1_2_3/abs_STD.txt')[1:9]
s2 = np.loadtxt(path + '3_4_5/abs_STD.txt')[1:9]
s3 = np.loadtxt(path + '5_6_7/abs_STD.txt')[1:9]
s4 = np.loadtxt(path + '7_8_9/abs_STD.txt')[1:9]
s5 = np.loadtxt(path + '9_10_11/abs_STD.txt')[1:9]
s6 = np.loadtxt(path + '11_12_13/abs_STD.txt')[1:9]
s7 = np.loadtxt(path + '13_14_15/abs_STD.txt')[1:9]

# %%
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/training variation - test performance/8_10_12/"

#  percentage sampled
# p = [60, 20, 0.1]
p = [80, 60, 40, 20, 10, 1, 0.5, 0.1]

# m1 = np.loadtxt(path + 'abs_error.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')


# # # # # window: [8,10,12] test on 11
# ax = plt.plot(p, m1,color='lightcoral', linewidth=10, linestyle='--', markersize = 30,marker = "D", markeredgecolor='black',label = "[8,10,12] tested on 11")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "lightcoral")

# window: [1,2,3]
ax = plt.plot(p, m1,color='lightcoral', linewidth=10, linestyle='--', markersize = 30,marker = "D", markeredgecolor='black',label = "[1,5,10]")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "lightcoral")

# window: [3,4,5]
ax = plt.plot(p, m2,color='orange', linewidth=10, linestyle='--', markersize = 30,marker = "1", markeredgecolor='black',label = "[10,15,20]")
# plt.fill_between(p, m2-s2,m2+s2,alpha=.4, facecolor = "orange")

# window: [5,6,7]
ax = plt.plot(p, m3,color='brown', linewidth=10, linestyle='--', markersize = 30,marker = "2", markeredgecolor='black',label = "[20,25,30]")
# plt.fill_between(p, m3-s3,m3+s3,alpha=.4, facecolor = "brown")

# window: [7,8,9]
ax = plt.plot(p, m4,color='blue', linewidth=10, linestyle='--', markersize = 30,marker = "3", markeredgecolor='black',label = "[30,35,40]")
# plt.fill_between(p, m4-s4,m4+s4,alpha=.4, facecolor = "blue")

# window: [9,10,11]
ax = plt.plot(p, m5,color='black', linewidth=10, linestyle='--', markersize = 30,marker = "4", markeredgecolor='black',label = "[40,45,50]")
# plt.fill_between(p, m5-s5,m5+s5,alpha=.4, facecolor = "black")

# window: [11,12,13]
ax = plt.plot(p, m6,color='yellow', linewidth=10, linestyle='--', markersize = 30,marker = "s", markeredgecolor='black',label = "[50,55,60]")
# plt.fill_between(p, m6-s6,m6+s6,alpha=.4, facecolor = "yellow")

# window: [13,14,15]
ax = plt.plot(p, m7,color='red', linewidth=10, linestyle='--', markersize = 30,marker = "*", markeredgecolor='black',label = "[60,65,70]")
# plt.fill_between(p, m7-s7,m7+s7,alpha=.4, facecolor = "red")

# window: [1,2,3]
ax = plt.plot(p, m8,color='darkviolet', linewidth=10, linestyle='--', markersize = 30,marker = "3", markeredgecolor='black',label = "[70,75,80]")
# plt.fill_between(p, m8-s8,m8+s8,alpha=.4, facecolor = "darkviolet")

# window: [3,4,5]
ax = plt.plot(p, m9,color='gray', linewidth=10, linestyle='--', markersize = 30,marker = "4", markeredgecolor='black',label = "[80,85,90]")
# plt.fill_between(p, m9-s9,m9+s9,alpha=.4, facecolor = "gray")

# window: [5,6,7]
ax = plt.plot(p, m10,color='teal', linewidth=10, linestyle='--', markersize = 30,marker = "s", markeredgecolor='black',label = "[90,95,100]")
# plt.fill_between(p, m10-s10,m10+s10,alpha=.4, facecolor = "teal")



plt.legend(loc = 'upper right')
plt.xscale('log')
# plt.title('Train Bombing network - STAGE 0', fontsize = 60)
plt.title('Virgili Emails network - STAGE 0', fontsize = 60)
# plt.title('Facebook network - STAGE 0', fontsize = 60)
plt.xlabel('Percentage of entries sampled', fontsize = 60)
plt.ylabel('AHDE', fontsize = 60)
plt.rcParams['figure.figsize'] = [25,18]

# We change the fontsize of minor ticks label 
plt.tick_params(axis='both', which='major', labelsize=40)
plt.tick_params(axis='both', which='minor', labelsize=40)
plt.rc('legend',fontsize=40)

# fname = 'virgili_results_window_comparisons.png'
# # # plt.savefig(fname, dpi=1000)
# path = 'C:/Users/gunjan/Google Drive/PhD work/Projects/HA Journal version/results/training variations/'
# plt.savefig(path + fname)

plt.show()
