# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  
import math
import seaborn as sns
import pandas as pa

# %% [markdown]
# ## Mean error

# %%
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 1/"
m1 = np.loadtxt(path + '10_11_12/mean_error.txt')
m1
# Out:
# array([25.08060801, 25.61881188, 26.45598194, 26.81940701, 29.34782609,
#        20.3125    , 20.58823529, 35.71428571])

# %% [markdown]
# For sensitivity error plot

# %%
#  percentage sampled
# p = [40, 20, 10, 1, 0.5, 0.1, 0.0001]
p = [80, 60, 40, 20, 10, 1, 0.5, 0.1]

# load from a file: MEAN ERROR

path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 1/"

# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/stage 1/"


# m1 = np.loadtxt(path + '8_10_12/mean_error.txt')[1:]

# m1 = np.loadtxt(path + '1_2_3/mean_error.txt')
# m2 = np.loadtxt(path + '3_4_5/mean_error.txt')
# m3 = np.loadtxt(path + '5_6_7/mean_error.txt')
# m4 = np.loadtxt(path + '7_8_9/mean_error.txt')
# m5 = np.loadtxt(path + '9_10_11/mean_error.txt')
# m6 = np.loadtxt(path + '11_12_13/mean_error.txt')
# m7 = np.loadtxt(path + '13_14_15/mean_error.txt')

m1 = np.loadtxt(path + '10_11_12/mean_error.txt')
m2 = np.loadtxt(path + '12_13_14/mean_error.txt')
m3 = np.loadtxt(path + '14_15_16/mean_error.txt')
m4 = np.loadtxt(path + '16_17_18/mean_error.txt')
m5 = np.loadtxt(path + '18_19_20/mean_error.txt')

# %%
np.mean(m1),np.mean(m2),np.mean(m3),np.mean(m4),np.mean(m5)
# Out:
# (27.411484074303832,
#  24.916802169299636,
#  29.648332347685486,
#  32.30493767895137,
#  29.603818129623935)

# %%
# load from a file: std dev for mean error

path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/stage 1/"

# s1 = np.loadtxt(path + '8_10_12/mean_std.txt')[1:]
                
s1 = np.loadtxt(path + '1_2_3/mean_STD.txt')
s2 = np.loadtxt(path + '3_4_5/mean_STD.txt')
s3 = np.loadtxt(path + '5_6_7/mean_STD.txt')
s4 = np.loadtxt(path + '7_8_9/mean_STD.txt')
s5 = np.loadtxt(path + '9_10_11/mean_STD.txt')
s6 = np.loadtxt(path + '11_12_13/mean_STD.txt')
s7 = np.loadtxt(path + '13_14_15/mean_STD.txt')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
len(m5)
# Out:
# 9

# %%
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/training variation - test performance/8_10_12/"


#  percentage sampled
# p = [60, 20, 0.1]
# deletion % = 20, 40, 60, 80, 90, 99, 99,5, 99.9
p = [80, 60, 40, 20, 10, 1, 0.5, 0.1]

# m1 = np.loadtxt(path + 'mean_error.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')


# # # # # window: [8,10,12] test on 11
# ax = plt.plot(p, m1,color='lightcoral', linewidth=10, linestyle='--', markersize = 30,marker = "D", markeredgecolor='black',label = "[8,10,12] tested on 11")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "lightcoral")


# # window: [1,2,3]
# ax = plt.plot(p, m1,color='lightcoral', linewidth=10, linestyle='--', markersize = 30,marker = "D", markeredgecolor='black',label = "[1,2,3]")
# # plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "lightcoral")

# # window: [3,4,5]
# ax = plt.plot(p, m2,color='orange', linewidth=10, linestyle='--', markersize = 30,marker = "1", markeredgecolor='black',label = "[3,4,5]")
# # plt.fill_between(p, m2-s2,m2+s2,alpha=.4, facecolor = "orange")

# # window: [5,6,7]
# ax = plt.plot(p, m3,color='brown', linewidth=10, linestyle='--', markersize = 30,marker = "2", markeredgecolor='black',label = "[5,6,7]")
# # plt.fill_between(p, m3-s3,m3+s3,alpha=.4, facecolor = "brown")

# # window: [7,8,9]
# ax = plt.plot(p, m4,color='blue', linewidth=10, linestyle='--', markersize = 30,marker = "3", markeredgecolor='black',label = "[7,8,9]")
# # plt.fill_between(p, m4-s4,m4+s4,alpha=.4, facecolor = "blue")

# # window: [9,10,11]
# ax = plt.plot(p, m5,color='black', linewidth=10, linestyle='--', markersize = 30,marker = "4", markeredgecolor='black',label = "[9,10,11]")
# # plt.fill_between(p, m5-s5,m5+s5,alpha=.4, facecolor = "black")

# # window: [11,12,13]
# ax = plt.plot(p, m6,color='yellow', linewidth=10, linestyle='--', markersize = 30,marker = "s", markeredgecolor='black',label = "[11,12,13]")
# # plt.fill_between(p, m6-s6,m6+s6,alpha=.4, facecolor = "yellow")

# # window: [13,14,15]
# ax = plt.plot(p, m7,color='red', linewidth=10, linestyle='--', markersize = 30,marker = "*", markeredgecolor='black',label = "[13,14,15]")
# # plt.fill_between(p, m7-s7,m7+s7,alpha=.4, facecolor = "red")

# ---------------train bombing-------------

# window: [1,2,3]
ax = plt.plot(p, m1,color='lightcoral', linewidth=10, linestyle='--', markersize = 30,marker = "D", markeredgecolor='black',label = "[10,11,12]")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "lightcoral")

# window: [3,4,5]
ax = plt.plot(p, m2,color='orange', linewidth=10, linestyle='--', markersize = 30,marker = "1", markeredgecolor='black',label = "[12,13,14]")
# plt.fill_between(p, m2-s2,m2+s2,alpha=.4, facecolor = "orange")

# window: [5,6,7]
ax = plt.plot(p, m3,color='brown', linewidth=10, linestyle='--', markersize = 30,marker = "2", markeredgecolor='black',label = "[14,15,16]")
# plt.fill_between(p, m3-s3,m3+s3,alpha=.4, facecolor = "brown")

# window: [7,8,9]
ax = plt.plot(p, m4,color='blue', linewidth=10, linestyle='--', markersize = 30,marker = "3", markeredgecolor='black',label = "[16,17,18]")
# plt.fill_between(p, m4-s4,m4+s4,alpha=.4, facecolor = "blue")

# window: [9,10,11]
ax = plt.plot(p, m5,color='black', linewidth=10, linestyle='--', markersize = 30,marker = "4", markeredgecolor='black',label = "[18,19,20]")
# plt.fill_between(p, m5-s5,m5+s5,alpha=.4, facecolor = "black")


plt.legend()
plt.xscale('log')
plt.title('Train Bombing network - STAGE I', fontsize = 60)
# plt.title('Facebook network - STAGE I', fontsize = 60)
plt.xlabel('Percentage of entries sampled', fontsize = 60)
plt.ylabel('Mean Error', fontsize = 60)
plt.rcParams['figure.figsize'] = [25, 18]

# We change the fontsize of minor ticks label 
plt.tick_params(axis='both', which='major', labelsize=40)
plt.tick_params(axis='both', which='minor', labelsize=40)
plt.rc('legend',fontsize=40)

# fname = 'virgili_results_window_comparisons.png'
# # # plt.savefig(fname, dpi=1000)
# path = 'C:/Users/gunjan/Google Drive/PhD work/Projects/HA Journal version/results/training variations/'
# plt.savefig(path + fname)

plt.show()

# %%
#  percentage sampled
# p = [40, 20, 10, 1, 0.5, 0.1, 0.0001]
p = [80, 60, 40, 20, 10, 1, 0.5, 0.1, 0.0001]

# load from a file: ABS ERROR

path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/stage 1/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 1/"

# m1 = np.loadtxt(path + '8_10_12/abs_error.txt')[1:]

# path = "C:/Users/gunjan/Google Drive/PhD work/Projects/parameter estimation/virgili/"

m1 = np.loadtxt(path + '1_2_3/abs_error.txt')
m2 = np.loadtxt(path + '3_4_5/abs_error.txt')
m3 = np.loadtxt(path + '5_6_7/abs_error.txt')
m4 = np.loadtxt(path + '7_8_9/abs_error.txt')
m5 = np.loadtxt(path + '9_10_11/abs_error.txt')
# m6 = np.loadtxt(path + '11_12_13/abs_error.txt')
# m7 = np.loadtxt(path + '13_14_15/abs_error.txt')



# # train bombing:
# m1 = np.loadtxt(path + '10_11_12/abs_error.txt')
# m2 = np.loadtxt(path + '12_13_14/abs_error.txt')
# m3 = np.loadtxt(path + '14_15_16/abs_error.txt')
# m4 = np.loadtxt(path + '16_17_18/abs_error.txt')
# m5 = np.loadtxt(path + '18_19_20/abs_error.txt')

# %%
# load from a file:

path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/"

# s1 = np.loadtxt(path + '8_10_12/abs_std.txt')[1:]


# path = "C:/Users/gunjan/Google Drive/PhD work/Projects/parameter estimation/virgili/"

s1 = np.loadtxt(path + '1_2_3/abs_STD.txt')
s2 = np.loadtxt(path + '3_4_5/abs_STD.txt')
s3 = np.loadtxt(path + '5_6_7/abs_STD.txt')
s4 = np.loadtxt(path + '7_8_9/abs_STD.txt')
s5 = np.loadtxt(path + '9_10_11/abs_STD.txt')
s6 = np.loadtxt(path + '11_12_13/abs_STD.txt')
s7 = np.loadtxt(path + '13_14_15/abs_STD.txt')

# %%
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/training variation - test performance/8_10_12/"

#  percentage sampled
# p = [60, 20, 0.1]
p = [80, 60, 40, 20, 10, 1, 0.5, 0.1]

# m1 = np.loadtxt(path + 'abs_error.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')


# # # # # window: [8,10,12] test on 11
# ax = plt.plot(p, m1,color='lightcoral', linewidth=10, linestyle='--', markersize = 30,marker = "D", markeredgecolor='black',label = "[8,10,12] tested on 11")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "lightcoral")


# window: [1,2,3]
ax = plt.plot(p, m1,color='lightcoral', linewidth=10, linestyle='--', markersize = 30,marker = "D", markeredgecolor='black',label = "[1,2,3]")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "lightcoral")

# window: [3,4,5]
ax = plt.plot(p, m2,color='orange', linewidth=10, linestyle='--', markersize = 30,marker = "1", markeredgecolor='black',label = "[3,4,5]")
# plt.fill_between(p, m2-s2,m2+s2,alpha=.4, facecolor = "orange")

# window: [5,6,7]
ax = plt.plot(p, m3,color='brown', linewidth=10, linestyle='--', markersize = 30,marker = "2", markeredgecolor='black',label = "[5,6,7]")
# plt.fill_between(p, m3-s3,m3+s3,alpha=.4, facecolor = "brown")

# window: [7,8,9]
ax = plt.plot(p, m4,color='blue', linewidth=10, linestyle='--', markersize = 30,marker = "3", markeredgecolor='black',label = "[7,8,9]")
# plt.fill_between(p, m4-s4,m4+s4,alpha=.4, facecolor = "blue")

# window: [9,10,11]
ax = plt.plot(p, m5,color='black', linewidth=10, linestyle='--', markersize = 30,marker = "4", markeredgecolor='black',label = "[9,10,11]")
# plt.fill_between(p, m5-s5,m5+s5,alpha=.4, facecolor = "black")

# # window: [11,12,13]
# ax = plt.plot(p, m6,color='yellow', linewidth=10, linestyle='--', markersize = 30,marker = "s", markeredgecolor='black',label = "[11,12,13]")
# # plt.fill_between(p, m6-s6,m6+s6,alpha=.4, facecolor = "yellow")

# # window: [13,14,15]
# ax = plt.plot(p, m7,color='red', linewidth=10, linestyle='--', markersize = 30,marker = "*", markeredgecolor='black',label = "[13,14,15]")
# # plt.fill_between(p, m7-s7,m7+s7,alpha=.4, facecolor = "red")




# # ---------------train bombing-------------

# # window: [1,2,3]
# ax = plt.plot(p, m1,color='lightcoral', linewidth=10, linestyle='--', markersize = 30,marker = "D", markeredgecolor='black',label = "[10,11,12]")
# # plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "lightcoral")

# # window: [3,4,5]
# ax = plt.plot(p, m2,color='orange', linewidth=10, linestyle='--', markersize = 30,marker = "1", markeredgecolor='black',label = "[12,13,14]")
# # plt.fill_between(p, m2-s2,m2+s2,alpha=.4, facecolor = "orange")

# # window: [5,6,7]
# ax = plt.plot(p, m3,color='brown', linewidth=10, linestyle='--', markersize = 30,marker = "2", markeredgecolor='black',label = "[14,15,16]")
# # plt.fill_between(p, m3-s3,m3+s3,alpha=.4, facecolor = "brown")

# # window: [7,8,9]
# ax = plt.plot(p, m4,color='blue', linewidth=10, linestyle='--', markersize = 30,marker = "3", markeredgecolor='black',label = "[16,17,18]")
# # plt.fill_between(p, m4-s4,m4+s4,alpha=.4, facecolor = "blue")

# # window: [9,10,11]
# ax = plt.plot(p, m5,color='black', linewidth=10, linestyle='--', markersize = 30,marker = "4", markeredgecolor='black',label = "[18,19,20]")
# # plt.fill_between(p, m5-s5,m5+s5,alpha=.4, facecolor = "black")





plt.legend(loc = 'upper right')
plt.xscale('log')
# plt.title('Train Bombing network - STAGE I', fontsize = 60)
# plt.title('Facebook network - STAGE I', fontsize = 60)
plt.title('Virgili Emails network - STAGE I', fontsize = 60)
plt.xlabel('Percentage of entries sampled', fontsize = 60)
plt.ylabel('AHDE', fontsize = 60)
plt.rcParams['figure.figsize'] = [25,18]

# We change the fontsize of minor ticks label 
plt.tick_params(axis='both', which='major', labelsize=40)
plt.tick_params(axis='both', which='minor', labelsize=40)
plt.rc('legend',fontsize=40)

# fname = 'virgili_results_window_comparisons.png'
# # # plt.savefig(fname, dpi=1000)
# path = 'C:/Users/gunjan/Google Drive/PhD work/Projects/HA Journal version/results/training variations/'
# plt.savefig(path + fname)

plt.show()
