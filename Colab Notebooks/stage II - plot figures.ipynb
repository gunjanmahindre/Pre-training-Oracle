# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  
import math
import seaborn as sns
import pandas as pa

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Mean error

# %%
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 2/"
m1 = np.loadtxt(path + '12_13_14/mean_error.txt')

m1
# Out:
# array([28.02400739, 29.25216598, 30.42056075, 33.26762523, 36.71249743,
#        40.06715165, 39.31552588, 39.73791067])

# %% [markdown]
# For sensitivity error plot

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
len(m5)
# Out:
# 9

# %%
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/MC/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/MC/"
m1 = np.loadtxt(path + 'mean_result.txt')
m1
# Out:
# array([ 1.4207863 ,  2.32748573,  4.0630339 ,  6.46949183,  9.52273402,
#        70.52450015, 72.20489427])

# %%
#  percentage sampled
# deletion % = 20, 40, 60, 80, 90, 99, 99,5, 99.9
p = [80, 60, 40, 20, 10, 1, 0.5, 0.1]




# stage II - Trivial 0
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/trivial 0/12_13_14/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/trivial 0/12_13_14/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/trivial 0/5_7_9/"
m1 = np.loadtxt(path + 'mean_error.txt')
s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='purple', linewidth=10, linestyle='--', markersize = 30,marker = "1", markeredgecolor='black',label = "Trivial 0")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "purple")


# stage II - Trivial 1
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/trivial 1/12_13_14/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/trivial 1/12_13_14/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/trivial 1/5_7_9/"
m1 = np.loadtxt(path + 'mean_error.txt')
s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='purple', linewidth=10, linestyle='--', markersize = 30,marker = "2", markeredgecolor='black',label = "Trivial 1")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "purple")

# # # # stage II - recovered by MC
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/MC/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/MC/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/MC/"
m1 = np.loadtxt(path + 'mean_result.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='black', linewidth=10, linestyle='--', markersize = 30,marker = "s", markeredgecolor='black', label = "MC")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "black")





# stage II - Trained only on observed entries
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/train on only observed entries/12_13_14/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/train on only observed entries/12_13_14/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/train on only observed entries/5_7_9/"
m1 = np.loadtxt(path + 'mean_error.txt')
s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='black', linewidth=10, linestyle='--', markersize = 30,marker = "3", markeredgecolor='black',label = "Trained on observed")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "black")


# stage II powerlaw 
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/stage 2 powerlaw/5_7_9/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/stage 2 powerlaw/5_7_9/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 2 powerlaw/12_13_14/"
m1 = np.loadtxt(path + 'mean_error.txt')
s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='orange', linewidth=10, linestyle='--', markersize = 30,marker = "*", markeredgecolor='black',label = "[5,7,9] - Powerlaw 8")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "orange")



# stage II nw
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/stage 2/5_7_9/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/stage 2/5_7_9/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 2/12_13_14/"
m1 = np.loadtxt(path + 'mean_error.txt')
s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='lightcoral', linewidth=10, linestyle='--', markersize = 30,marker = "*", markeredgecolor='black',label = "[5,7,9] - Network")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "lightcoral")


# stage II - FINE TUNING
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/stage 2 fine tune/5_7_9/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 2 fine tune/12_13_14/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/fine tuning/5_7_9/"
m1 = np.loadtxt(path + 'mean_error.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='cyan', linewidth=10, linestyle='--', markersize = 30,marker = "*", markeredgecolor='black',label = "[5,7,9] - Network, fine tuned")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "cyan")



plt.legend(loc = 'upper right')
plt.xscale('log')
# plt.title('Virgili Emails network - STAGE II', fontsize = 60)
# plt.title('Facebook network - STAGE II', fontsize = 60)
plt.title('Train Bombing network - STAGE II', fontsize = 60)
plt.xlabel('Percentage of entries sampled', fontsize = 60)
plt.ylabel('Mean Error', fontsize = 60)
plt.rcParams['figure.figsize'] = [25,18]

# We change the fontsize of minor ticks label 
plt.tick_params(axis='both', which='major', labelsize=40)
plt.tick_params(axis='both', which='minor', labelsize=40)
plt.rc('legend',fontsize=40)

# fname = 'virgili_results_window_comparisons.png'
# # # plt.savefig(fname, dpi=1000)
# path = 'C:/Users/gunjan/Google Drive/PhD work/Projects/HA Journal version/results/training variations/'
# plt.savefig(path + fname)

plt.show()

# %%
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/MC/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/MC/"
m1 = np.loadtxt(path + 'hop_result.txt')
m1
# Out:
# array([0.01006786, 0.03353117, 0.08783498, 0.1864866 , 0.30876731,
#        1.82891931, 2.52816406, 2.59884949])

# %%
#  percentage sampled
# deletion % = 20, 40, 60, 80, 90, 99, 99,5, 99.9
p = [80, 60, 40, 20, 10, 1, 0.5, 0.1]




# stage II - Trivial 0
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/trivial 0/12_13_14/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/trivial 0/12_13_14/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/trivial 0/5_7_9/"
m1 = np.loadtxt(path + 'abs_error.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='purple', linewidth=10, linestyle='--', markersize = 30,marker = "1", markeredgecolor='black',label = "Trivial 0")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "purple")


# stage II - Trivial 1
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/trivial 1/12_13_14/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/trivial 1/12_13_14/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/trivial 1/5_7_9/"
m1 = np.loadtxt(path + 'abs_error.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='purple', linewidth=10, linestyle='--', markersize = 30,marker = "2", markeredgecolor='black',label = "Trivial 1")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "purple")


# # # # stage II - recovered by MC
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/MC/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/MC/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/MC/"
m1 = np.loadtxt(path + 'hop_result.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='black', linewidth=10, linestyle='--', markersize = 30,marker = "s", markeredgecolor='black', label = "MC")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "black")




# stage II - Trained only on observed entries
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/train on only observed entries/12_13_14/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/train on only observed entries/12_13_14/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/train on only observed entries/5_7_9/"
m1 = np.loadtxt(path + 'abs_error.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='black', linewidth=10, linestyle='--', markersize = 30,marker = "3", markeredgecolor='black',label = "Trained on observed")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "black")


# stage II powerlaw 
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/stage 2 powerlaw/5_7_9/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/stage 2 powerlaw/5_7_9/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 2 powerlaw/12_13_14/"
m1 = np.loadtxt(path + 'abs_error.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='orange', linewidth=10, linestyle='--', markersize = 30,marker = "*", markeredgecolor='black',label = "[5,7,9] - Powerlaw 8")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "orange")



# stage II nw
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/stage 2/5_7_9/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/stage 2/5_7_9/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 2/12_13_14/"
m1 = np.loadtxt(path + 'abs_error.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='lightcoral', linewidth=10, linestyle='--', markersize = 30,marker = "*", markeredgecolor='black',label = "[5,7,9] - Network")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "lightcoral")




# stage II - FINE TUNING
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/bigger facebokk results/stage 2 fine tune/5_7_9/"
path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/train bombing/stage 2 fine tune/12_13_14/"
# path = "/content/drive/MyDrive/PhD work/Projects/parameter estimation/virgili more results/fine tuning/5_7_9/"
m1 = np.loadtxt(path + 'abs_error.txt')
# s1 = np.loadtxt(path + 'mean_STD.txt')
# # # # window: 
ax = plt.plot(p, m1,color='cyan', linewidth=10, linestyle='--', markersize = 30,marker = "*", markeredgecolor='black',label = "[5,7,9] - Network, fine tuned")
# plt.fill_between(p, m1-s1,m1+s1,alpha=.4, facecolor = "cyan")







plt.legend(loc = 'upper right')
plt.xscale('log')
# plt.title('Facebook network - STAGE II', fontsize = 60)
# plt.title('Virgili Emails network - STAGE II', fontsize = 60)
plt.title('Train Bombing network - STAGE II', fontsize = 60)
plt.xlabel('Percentage of entries sampled', fontsize = 60)
plt.ylabel('AHDE', fontsize = 60)
plt.rcParams['figure.figsize'] = [25,18]

# We change the fontsize of minor ticks label 
plt.tick_params(axis='both', which='major', labelsize=40)
plt.tick_params(axis='both', which='minor', labelsize=40)
plt.rc('legend',fontsize=40)

# fname = 'virgili_results_window_comparisons.png'
# # # plt.savefig(fname, dpi=1000)
# path = 'C:/Users/gunjan/Google Drive/PhD work/Projects/HA Journal version/results/training variations/'
# plt.savefig(path + fname)

plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
